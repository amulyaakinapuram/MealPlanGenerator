# %%
import os

# Specify the directory path containing the files
directory_path = 'resturant/data/data'

# List all files in the directory
files = os.listdir(directory_path)

# Iterate through the files and rename them
for filename in files:
    # Split the filename by the dot (.)
    parts = filename.split('.')
    
    # Check if the filename has at least 2 parts (i.e., it starts with a number followed by a dot)
    if len(parts) >= 2:
        # Extract the part after the first dot and strip any leading/trailing whitespace
        new_filename = parts[1].strip()
        
        # Create the new path for the file
        old_path = os.path.join(directory_path, filename)
        new_path = os.path.join(directory_path, new_filename)
        
        # Rename the file
        os.rename(old_path, new_path)

print("File names have been updated.")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[10], line 24
#      21         new_path = os.path.join(directory_path, new_filename)
#      23         # Rename the file
# ---> 24         os.rename(old_path, new_path)
#      26 print("File names have been updated.")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'resturant/data/data\\1.jpg' -> 'resturant/data/data\\jpg'

# %%
file_names
# Out:
# ['1-long-format-Besan_Pyaaz_Ka_Cheela_Recipe_Figaro_Olive_Oil-4.jpg',
#  '10-long-format-Spicy_Egg_Biryani_Recipe_Figaro_Olive_Oil_Video_Recipe-1.jpg',
#  '1048.Papad_er_Dalna_bengali_style_papad_curry_Recipe-2.jpg',
#  '1080.Matar_Ki_Tehri_recipe-1.jpg',
#  '1094.Dalia_Khichdi_Recipe_Broken_Wheat_Khichdi-1_preview.jpeg',
#  '1099.Kuruku_Kaalan_Recipe_Raw_Bananas_in_Coconut_Curry-7.jpg',
#  '10_-_Ukad_Recipe_Maharashtrian_Rice_Flour_Porridge_2_1600.jpg',
#  '11-long-format-Punjabi_Lobia_Masala_Figaro_Olive_Oil-2.jpg',
#  '1106.Vankaya_Kothimeera_Karam_Recipe_Andhra_Style_Brinjals_Cooked_With_Spicy_Coriander_Mix-5.jpg',
#  '1120.Orange_Rasam_Recipe-7.jpg',
#  '1140.Lehsun_Chutney_Garlic_Chutney_Video_Recipe_7_1600.jpg',
#  '1144.Pyaz_Ki_Kadhi_Recipe-2_1600.jpg',
#  '1147.Aluchi_Bhaji_Maharastrian_Colacasia_leaves_curry_with_peanuts-1.jpg',
#  '1150.Preethi_Kitchen_Appliances_Ellu_Sesame_Seed_Chutney_Thogayal_Video_recipe_5_Delicious_Chutneys_You_Can_Make_With_Turbo_Chop-1.jpg',
# ...
